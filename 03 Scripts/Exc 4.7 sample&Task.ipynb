# %% [markdown]
# # Importing libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import os

# %%
def cal_sum(a,b):
    sum=a+b
    return sum

# %%
cal_sum(9,11)
# Out:
# 20

# %% [markdown]
# # Import data

# %%
df_ords_prods_merge=pd.read_pickle(r'D:\Sonal\career foundry\CareerFoundry\Data Immersion\Achievement 4\Exc 4.3\Prepared data\ords_prods_merge.pkl')

# %%
df_ords_prods_merge.shape
# Out:
# (32404859, 14)

# %%
df=df_ords_prods_merge[:1000000]

# %%
df.shape
# Out:
# (1000000, 14)

# %% [markdown]
# # Create if_elif_else Function

# %%
def price_label(row):

  if row['prices'] <= 5:
    return 'Low-range product'
  elif (row['prices'] > 5) and (row['prices'] <= 15):
    return 'Mid-range product'
  elif row['prices'] > 15:
    return 'High range product'
  else: return np.nan

# %%
#Apply the function

# %%
df['price_range'] = df.apply(price_label, axis=1)
# Out:
# C:\Users\nmsp1\AppData\Local\Temp\ipykernel_27240\2848743372.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_range'] = df.apply(price_label, axis=1)

# %%
df.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# ...

# %%
df['price_range'].value_counts(dropna=False)
# Out:
# price_range
# Mid-range product     652638
# Low-range product     338018
# High range product      9344
# Name: count, dtype: int64

# %%
df['prices'].max()
# Out:
# 24.5

# %% [markdown]
# # If statement with loc()function

# %%
df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'
# Out:
# C:\Users\nmsp1\AppData\Local\Temp\ipykernel_27240\1169838859.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.loc[df['prices'] > 15, 'price_range_loc'] = 'High-range product'

# %%
df.loc[(df['prices'] <= 15) & (df['prices'] > 5), 'price_range_loc'] = 'Mid-range product'

# %%
df.loc[df['prices'] <= 5, 'price_range_loc'] = 'Low-range product'

# %%
df['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid-range product     652638
# Low-range product     338018
# High-range product      9344
# Name: count, dtype: int64

# %%
#if statement on df_ords_prods_merge

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] > 15, 'price_range_loc']='High_range_product'

# %%
df_ords_prods_merge.loc[(df_ords_prods_merge['prices'] <=15) & (df_ords_prods_merge['prices'] > 5), 'price_range_loc']='Mid_range_product'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['prices'] <=5, 'price_range_loc']='Low_range_product'

# %%
df_ords_prods_merge['price_range_loc'].value_counts(dropna=False)
# Out:
# price_range_loc
# Mid_range_product     21860860
# Low_range_product     10126321
# High_range_product      417678
# Name: count, dtype: int64

# %% [markdown]
# # If statement FOR Loops

# %%
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna=False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
result = []
for value in df_ords_prods_merge["orders_day_of_week"]:
     if value == 0:
         result.append("Busiest day")
     elif value == 4:
        result.append("Least busy")
     else:
        result.append("Regularly busy")

# %%
df_ords_prods_merge['busiest_day']=result

# %%
df_ords_prods_merge['busiest_day'].value_counts(dropna=False)
# Out:
# busiest_day
# Regularly busy    22416875
# Busiest day        6204182
# Least busy         3783802
# Name: count, dtype: int64

# %%
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# ...

# %% [markdown]
# # Task

# %% [markdown]
# # Create a new column, they want “Busiest day” to become “Busiest days” (plural) and  two slowest days.

# %%
#  to know on which day most orders take place. we can find this out by printing the frequency of the “orders_day_of_week” column

# %%
df_ords_prods_merge['orders_day_of_week'].value_counts(dropna=False)
# Out:
# orders_day_of_week
# 0    6204182
# 1    5660230
# 6    4496490
# 2    4213830
# 5    4205791
# 3    3840534
# 4    3783802
# Name: count, dtype: int64

# %%
# using FOR Loop if statement function

# %%
result = []
for value in df_ords_prods_merge["orders_day_of_week"]:
    if value==0 or value==1:
        result.append("Busiest days")
    elif value==4 or value==3:
        result.append("Slowest days")
    else:
        result.append("Regular busy")

# %%
result
# Out:
# ['Regular busy',
#  'Regular busy',
#  'Busiest days',
#  'Slowest days',
#  'Slowest days',
#  'Busiest days',
#  'Regular busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Regular busy',
#  'Slowest days',
#  'Slowest days',
#  'Regular busy',
#  'Slowest days',
#  'Regular busy',
#  'Regular busy',
#  'Regular busy',
#  'Busiest days',
#  'Busiest days',
#  'Regular busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Regular busy',
#  'Busiest days',
#  'Busiest days',
#  'Regular busy',
#  'Regular busy',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
#  'Regular busy',
#  'Regular busy',
#  'Busiest days',
#  'Busiest days',
#  'Busiest days',
#  'Slowest days',
# ...

# %%
#Create new 'busiest_days' column in df_ords_prods_merge to view results in context.

# %%
df_ords_prods_merge['busiest_days']=result

# %%
# print the frequency of this new column and cross-check it with the frequency of “orders_day_of_week”  printed before.

# %%
df_ords_prods_merge['busiest_days'].value_counts(dropna=False)
# Out:
# busiest_days
# Regular busy    12916111
# Busiest days    11864412
# Slowest days     7624336
# Name: count, dtype: int64

# %%
#check output of ords_prods_merge with new "busiest days" column.

# %%
df_ords_prods_merge.head()
# Out:
#    product_id                product_name  aisle_id  department_id  prices  \
# 0           1  Chocolate Sandwich Cookies        61             19     5.8
# 1           1  Chocolate Sandwich Cookies        61             19     5.8
# 2           1  Chocolate Sandwich Cookies        61             19     5.8
# 3           1  Chocolate Sandwich Cookies        61             19     5.8
# 4           1  Chocolate Sandwich Cookies        61             19     5.8
#
#    order_id  user_id  order_number  orders_day_of_week  order_hour_of_day  \
# 0   3139998      138            28                   6                 11
# 1   1977647      138            30                   6                 17
# 2    389851      709             2                   0                 21
# 3    652770      764             1                   3                 13
# 4   1813452      764             3                   4                 17
#
#    days_since_prior_order  add_to_cart_order  reordered _merge  \
# ...

# %%
#drop the old column 'busiest_day'

# %%
df_ords_prods_merge.drop(columns=['busiest_day'])
# Out:
#           product_id                product_name  aisle_id  department_id  \
# 0                  1  Chocolate Sandwich Cookies        61             19
# 1                  1  Chocolate Sandwich Cookies        61             19
# 2                  1  Chocolate Sandwich Cookies        61             19
# 3                  1  Chocolate Sandwich Cookies        61             19
# 4                  1  Chocolate Sandwich Cookies        61             19
# ...              ...                         ...       ...            ...
# 32404854       49688      Fresh Foaming Cleanser        73             11
# 32404855       49688      Fresh Foaming Cleanser        73             11
# 32404856       49688      Fresh Foaming Cleanser        73             11
# 32404857       49688      Fresh Foaming Cleanser        73             11
# 32404858       49688      Fresh Foaming Cleanser        73             11
#
#           prices  order_id  user_id  order_number  orders_day_of_week  \
# ...

# %% [markdown]
# #  identify the busiest hours of the day, labeled “Most orders,” “Average orders,” and “Fewest orders

# %%
# using if statement using loc() function

# %%
# Check value counts in "order_hour_of_day" column.

# %%
df_ords_prods_merge['order_hour_of_day'].value_counts(dropna=False)
# Out:
# order_hour_of_day
# 10    2761760
# 11    2736140
# 14    2689136
# 15    2662144
# 13    2660954
# 12    2618532
# 16    2535202
# 9     2454203
# 17    2087654
# 8     1718118
# 18    1636502
# 19    1258305
# 20     976156
# 7      891054
# 21     795637
# 22     634225
# 23     402316
# 6      290493
# 0      218769
# 1      115700
# 5       87961
# 2       69375
# 4       53242
# 3       51281
# Name: count, dtype: int64

# %%
#The value counts listed above will be split into equal thirds for the following labels: "Most orders" = 10, 11, 14, 15, 13, 12, 16, and 9; "Fewest orders" = 23, 6, 0, 1, 5, 2, 4, and 3; "Average orders" = all remaining values in order_hour_of_day.

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['order_hour_of_day'].isin([10,11,14,15,13,12,16,9]),'busiest_period_of_day']='Most orders'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['order_hour_of_day'].isin([23,6,0,1,5,2,4,3]),'busiest_period_of_day']='Fewest orders'

# %%
df_ords_prods_merge.loc[df_ords_prods_merge['order_hour_of_day'].isin([17,8,18,19,20,7,21,22]),'busiest_period_of_day']='Average orders'

# %%
#Print frequency of "busiest_period_of_day" column.

# %%
df_ords_prods_merge['busiest_period_of_day'].value_counts(dropna=False)
# Out:
# busiest_period_of_day
# Most orders       21118071
# Average orders     9997651
# Fewest orders      1289137
# Name: count, dtype: int64

# %% [markdown]
# # Export dataframe as a pickle file to 'prepared data' folder

# %%
df_ords_prods_merge.to_pickle(r'D:\Sonal\career foundry\CareerFoundry\Data Immersion\Achievement 4\Exc 4.3\Prepared data\orders_products_merged_derived.pkl')
